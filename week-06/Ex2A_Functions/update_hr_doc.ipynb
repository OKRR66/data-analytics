# %% [markdown]
# ## Lab 3. Employee data This lab exercise makes updates to information extracted from an employee database.

# %%
hr_list = [
    ('0123', 'HR', 'Rebecca Yang', '69000'), 
    ('0121', 'IT', 'Mark Blick', '67000'), 
    ('0068', 'IT', 'Kahna Larsen', '112000'), 
    ('0234', 'OPS', 'Jim Smith', '54000')
]

# %%
hr_list[1] = ('0121', 'IT', 'Mark Blick-Hawley', '67000')

# %%
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'OPS', 'Jim Smith', '54000')]

# %%
hr_list[3] = ('0234', 'CS', 'Jim Smith', '60000')

# %%
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'CS', 'Jim Smith', '60000')]

# %%
#6a Add another code cell to display the updated contents on multiple lines in the following format:
#Use the pipe/bar character ( that’s | or shift+\ on your keyboard) to separate each value, 
#with a space on either side of the pipe character, and format the salary to use a comma: Employee# | DeptCode | Name | NN,NNN 
#Note: Formatting that last value can be deceptively tricky! Consider that you might 
#have to cast it as another data type when using the format function…

# %%
for i in hr_list:
    print(f"{i[0]} | {i[1]} | {i[2]} | {int(i[3])}")
# Out:
# 0123 | HR | Rebecca Yang | 69000
# 0121 | IT | Mark Blick-Hawley | 67000
# 0068 | IT | Kahna Larsen | 112000
# 0234 | CS | Jim Smith | 60000
