# %% [markdown]
# ## Lab 1
# # Exercise 2.C

# %%
#3)
def favorite_things(name, movie, music):
    return f"{name}\n{movie}\n{music}"
print(favorite_things("Onur Karaer","Interstellar","Ezhel"))
# Out:
# Onur Karaer
# Interstellar
# Ezhel

# %%
#4
def why_im_here(purpose):
    return purpose
print(why_im_here("I want to be a data analyst because I want to work with data and solve problems.\n\
And I believe my skills,wants and needs will be a great fit for this career path."))
# Out:
# I want to be a data analyst because I want to work with data and solve problems.
# And I believe my skills,wants and needs will be a great fit for this career path.

# %%
#5)
def favorite_place(place, why):
    print(f"My favorite place is {place} because {why}")
favorite_place("Rome", "I love history")
# Out:
# My favorite place is Rome because I love history
