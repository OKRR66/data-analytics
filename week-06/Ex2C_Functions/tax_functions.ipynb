# %% [markdown]
# # Ex2C Lab 3
# ## Tax Functions created

# %%
def get_soc_sec_tax(gross_income):
    tax_rate = 0.062
    tax_amount = gross_income * tax_rate
    return tax_amount

# %%
def get_medicare_tax(gross_income):
    tax_rate = 0.0145
    tax_amount = gross_income * tax_rate
    return tax_amount

# %%
#get_federal_tax(gross_income, withholding_code):
#    tax_rates = {
#        0: 0.23,
#        1: 0.21,
#        2: 0.195,
#        3: 0.185,
#        4: 0.18-(withholding_code-4)*0.005        
#    }
#    tax_rate = tax_rates.
#    tax_amount = gross_income * tax_rate
#    return tax_amount
#get_federal_tax(50000, 2)

## I tried to implement solution like above without using if else but couldn't figure it out.

def get_federal_tax(gross_income, withholding_code):
    if withholding_code == 0:
        tax_rate = 0.23
    elif withholding_code == 1:
        tax_rate = 0.21
    elif withholding_code == 2:
        tax_rate = 0.195
    elif withholding_code == 3:
        tax_rate = 0.185
    else:
        withholding_code >= 4
        tax_rate = 0.18 - (withholding_code - 4) * 0.005
    
    
    tax_amount = gross_income * tax_rate
    return tax_amount

# %%
get_federal_tax(750, 0)
# Out:
# 172.5

# %%
get_federal_tax(1550,2)
# Out:
# 302.25

# %%
get_federal_tax(1100,5)
# Out:
# 192.5
